# %% [markdown]
# # Books Recommender System using clustering | Coollaborative based

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('Books.csv', sep=",", error_bad_lines = False, encoding='latin-1')
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
books.head(2)
# Out:
#         ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  195153448  Classical Mythology    Mark P. O. Morford                2002
# 1    2005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  Unnamed: 8  Unnamed: 9  \
# 0  http://images.amazon.com/images/P/0195153448.0...         NaN         NaN
# 1  http://images.amazon.com/images/P/0002005018.0...         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# ...

# %%
books.dropna(axis=1)
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355   440400988                         There's a Bat in Bunk Five
# 271356   525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358   192126040                        Republic (World's Classics)
# 271359   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#        Year-Of-Publication                                        Image-URL-S  \
# ...

# %%
books.shape
# Out:
# (271360, 14)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
books.drop('Image-URL-M', axis=1, inplace=True)

# %%
books.drop('Image-URL-S', axis=1, inplace=True)

# %%
books.drop('Unnamed: 8', axis=1, inplace=True)

# %%
books.drop('Unnamed: 9', axis=1, inplace=True)

# %%
books.drop('Unnamed: 10', axis=1, inplace=True)

# %%
books.drop('Unnamed: 11', axis=1, inplace=True)

# %%
books.drop('Unnamed: 12', axis=1, inplace=True)

# %%
books.drop('Unnamed: 13', axis=1, inplace=True)

# %%
books.head(2)
# Out:
#         ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  195153448  Classical Mythology    Mark P. O. Morford                2002
# 1    2005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-L
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
books.shape
# Out:
# (271360, 6)

# %%
books.rename(columns={
    "Book-Title" : "title",
    "Book-Author" : "author",
    "Year-Of-Publication" : "year",
    "Publisher" : "publisher",
    "Image-URL-L" : "img-url"}, inplace = True)

# %%
books.head()
# Out:
#         ISBN                                              title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                              img-url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users = pd.read_csv('Users.csv', sep=",", error_bad_lines = False, encoding='latin-1')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv('Ratings.csv', sep=",", error_bad_lines = False, encoding='latin-1')

# %%
ratings.head(5)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings.rename(columns={
    "User-ID" : "user_id",
    "Book-Rating" : "rating"
}, inplace = True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings['user_id'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 271728        1
# 245123        1
# 234886        1
# 259466        1
# 187812        1
# Name: user_id, Length: 105283, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index

# %%
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             116122,  28634, 188951,  59727, 155916, 274808,  73681,   9856,
#             268622,  44296],
#            dtype='int64', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
books.head(2)
# Out:
#         ISBN                title                author  year  \
# 0  195153448  Classical Mythology    Mark P. O. Morford  2002
# 1    2005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher                                            img-url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
ratings_with_books = ratings.merge(books, on="ISBN")

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                              img-url
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
ratings_with_books.shape
# Out:
# (78797, 8)

# %%
num_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
num_rating.head()
# Out:
#                                                title  rating
# 0   Earth Prayers From around the World: 365 Pray...       3
# 1   Final Fantasy Anthology: Official Strategy Gu...       3
# 2   Flight of Fancy: American Heiresses (Zebra Ba...       1
# 3   Little Comic Shop of Horrors (Give Yourself G...       4
# 4                                       Mystery Mile       1

# %%
num_rating.rename(columns={
    "rating" : "num_of_rating"
},inplace=True)

# %%
num_rating.head()
# Out:
#                                                title  num_of_rating
# 0   Earth Prayers From around the World: 365 Pray...              3
# 1   Final Fantasy Anthology: Official Strategy Gu...              3
# 2   Flight of Fancy: American Heiresses (Zebra Ba...              1
# 3   Little Comic Shop of Horrors (Give Yourself G...              4
# 4                                       Mystery Mile              1

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                              img-url
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
final_rating = ratings_with_books.merge(num_rating, on='title')

# %%
final_rating.head(2)
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
#
#                                              img-url  num_of_rating
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/002542730X.0...             82

# %%
final_rating.shape
# Out:
# (78797, 9)

# %%
final_rating = final_rating[final_rating['num_of_rating']>=50]

# %%
final_rating.sample(10)
# Out:
#        user_id        ISBN  rating  \
# 9458    155147  068484477X       0
# 1896    162639  014025448X      10
# 4645    136382  074343627X       3
# 6060    178667  051513287X       0
# 250      56856  014100018X       0
# 14457   136139  1558745157       0
# 9291     13552  068484267X       0
# 9468    194600  068484477X       9
# 12161    16634  015100692X       9
# 10992    85526  1590400364       3
#
#                                                    title         author  year  \
# 9458                               STONES FROM THE RIVER    Ursula Hegi  1997
# 1896              At Home in Mitford (The Mitford Years)      Jan Karon  1996
# 4645                                        Dreamcatcher   Stephen King  2001
# 6060        Face the Fire (Three Sisters Island Trilogy)   Nora Roberts  2002
# 250                                             Chocolat  Joanne Harris  2000
# 14457  The Lost Boy: A Foster Child's Search for the ...    Dave Pelzer  1997
# ...

# %%
final_rating.shape
# Out:
# (5886, 9)

# %%
final_rating.drop_duplicates(['user_id','title'], inplace = True)

# %%
final_rating.shape
# Out:
# (5852, 9)

# %%
book_pivot = final_rating.pivot_table(columns='user_id', index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     NaN     NaN
# A Painted House                                        NaN     NaN     NaN
# A Patchwork Planet                                     NaN     NaN     NaN
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     0.0     NaN
# Turtle Moon                                            NaN     NaN     NaN
# Welcome to the World, Baby Girl!                       NaN     NaN     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (70, 810)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <70x810 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1480 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
print(book_pivot.shape)
# Out:
# (70, 810)

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[50,:].values.reshape(1,-1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 45.98912915, 46.84015371, 47.39198244, 47.78074926,
#         48.32183771]])

# %%
suggestion
# Out:
# array([[50, 63,  3, 56, 18, 49]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['The Color of Water: A Black Man's Tribute to His White Mother',
#        'The Reef', 'A Patchwork Planet', 'The Kiss', 'Cry Wolf',
#        'The Clinic (Alex Delaware Novels (Paperback))'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# 'A Patchwork Planet'

# %%
book_pivot.index
# Out:
# Index(['A Child Called \It\": One Child's Courage to Survive"',
#        'A Fine Balance', 'A Painted House', 'A Patchwork Planet',
#        'A Widow for One Year', 'All I Really Need to Know',
#        'Angela's Ashes: A Memoir',
#        'Anne of Green Gables (Anne of Green Gables Novels (Paperback))',
#        'At Home in Mitford (The Mitford Years)', 'Atonement : A Novel',
#        'Bag of Bones', 'Breath, Eyes, Memory', 'Breathing Lessons',
#        'Bridget Jones's Diary', 'Call of the Wild',
#        'Chicken Soup for the Soul (Chicken Soup for the Soul)',
#        'Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))',
#        'Chocolat', 'Cry Wolf', 'Degree of Guilt', 'Dreamcatcher',
#        'Face the Fire (Three Sisters Island Trilogy)', 'Fingersmith',
#        'Flesh and Blood',
#        'Forever... : A Novel of Good and Evil, Love and Hope',
#        'Full Tilt (Janet Evanovich's Full Series)', 'Girl in Hyacinth Blue',
# ...

# %%
book_name = book_pivot.index

# %%
import pickle 
pickle.dump(model, open('artifacts/model.pkl','wb'))
pickle.dump(book_name, open('artifacts/book_name.pkl','wb'))
pickle.dump(final_rating, open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot, open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6)
    
    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books: 
            print(j)

# %%
book_name = "Bridget Jones's Diary"
recommend_book(book_name)
# Out:
# Bridget Jones's Diary
# A Fine Balance
# The Kiss
# A Patchwork Planet
# Cry Wolf
# The Reef
